# %% [markdown]
# # LAB-2
#
# ### Author
#
# - [Navaneeth Sivakumar (21BAI1302)](https://github.com/Sivakumar-Navaneeth)

# %% [markdown]
# ### 1. read B/W image and display the negative

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('Data/zidane.jpg', cv2.IMREAD_GRAYSCALE)
img_negative = 255 - img

plt.imshow(img_negative)
plt.show()
